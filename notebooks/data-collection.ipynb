# %%
import os 
import pandas as pd
import json
import csv
import requests
import datetime
import dateutil.parser
import unicodedata
import time

# %%
keys = pd.read_csv("C:/Users/szkum/NetSI/keys/twitter-keys.csv")

# %%
os.environ['TOKEN'] = keys['BEARER_TOKEN'][0]

# %%
def auth():
    return os.getenv('TOKEN')

# %%
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

# %%
### TESTING USING /recent until I get the academic creds then going back to /all ##

def create_url_recent(keyword, start_date, end_date, max_results = 10):
    
    search_url = "https://api.twitter.com/2/tweets/search/recent" #Change to the endpoint you want to collect data from

    #change params based on the endpoint you are using
    query_params = {'query': keyword,
                    'start_time': start_date,
                    'end_time': end_date,
                    'max_results': max_results,
                    'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
                    'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
                    'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
                    'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
                    'next_token': {}}
    return (search_url, query_params)

# %%
def create_url(keyword, start_date, end_date, max_results = 10):
    
    search_url = "https://api.twitter.com/2/tweets/search/all" #Change to the endpoint you want to collect data from

    #change params based on the endpoint you are using
    query_params = {'query': keyword,
                    'start_time': start_date,
                    'end_time': end_date,
                    'max_results': max_results,
                    'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
                    'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
                    'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
                    'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
                    'next_token': {}}
    return (search_url, query_params)

# %%
def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
## Running a Search

# %%
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = "ebola"
start_time = "2022-11-02T00:00:00.000Z"
end_time = "2022-11-07T00:00:00.000Z"
max_results = 15

# %%
url = create_url(keyword, start_time,end_time, max_results)
json_response = connect_to_endpoint(url[0], headers, url[1])
# Out:
# Endpoint Response Code: 200

# %%
json_response
# Out:
# {'data': [{'referenced_tweets': [{'type': 'replied_to',
#      'id': '1589106068247875585'}],
#    'in_reply_to_user_id': '518957800',
#    'author_id': '2751880866',
#    'reply_settings': 'everyone',
#    'conversation_id': '1589063446649507840',
#    'id': '1589407031303491584',
#    'created_at': '2022-11-06T23:59:00.000Z',
#    'lang': 'en',
#    'source': 'Twitter for Android',
#    'text': '@KeepitdarkIan @BarryHunt008 Worked for smallpox, ebola, rabies and polio, right?',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'edit_history_tweet_ids': ['1589407031303491584']},
#   {'referenced_tweets': [{'type': 'retweeted', 'id': '1589369212413566976'}],
#    'author_id': '1213257465447403520',
#    'reply_settings': 'everyone',
#    'conversation_id': '1589406475306270720',
#    'id': '1589406475306270720',
#    'created_at': '2022-11-06T23:56:48.000Z',
#    'lang': 'es',
#    'source': 'Twitter for Android',
#    'text': 'RT @Ivanjode: El PP, partido condenado y más corrupto de Europa fue el gestor del Prestige, el Yak-42, el Ébola o el 11-M. Después de todo…',
#    'public_metrics': {'retweet_count': 726,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'edit_history_tweet_ids': ['1589406475306270720']},
#   {'referenced_tweets': [{'type': 'retweeted', 'id': '1588961620440813568'}],
#    'author_id': '1520550645794758656',
#    'reply_settings': 'everyone',
#    'conversation_id': '1589406370914533376',
#    'id': '1589406370914533376',
#    'created_at': '2022-11-06T23:56:23.000Z',
#    'lang': 'es',
#    'source': 'Twitter Web App',
#    'text': 'RT @richyuno64: El PP culpó del Jak42 a la cúpula militar\ndel 11M a ETA \nd la crisis del Ébola, a la enfermera\ndel accidente del Alvia, al…',
#    'public_metrics': {'retweet_count': 972,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'edit_history_tweet_ids': ['1589406370914533376']},
#   {'referenced_tweets': [{'type': 'retweeted', 'id': '1588813959704236033'}],
#    'author_id': '355299869',
#    'reply_settings': 'everyone',
#    'conversation_id': '1589406126436937728',
#    'id': '1589406126436937728',
#    'created_at': '2022-11-06T23:55:24.000Z',
#    'lang': 'it',
#    'source': 'Twitter Web App',
#    'text': "RT @ElGusty201: Bombe atomiche?\n\nNo! Pandemie.\n\nPutin ha invaso Ucraina perché il NWO, stava preparando per quest' autunno una febbre viral…",
#    'public_metrics': {'retweet_count': 171,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'edit_history_tweet_ids': ['1589406126436937728']},
#   {'referenced_tweets': [{'type': 'replied_to', 'id': '1589088654039093250'}],
#    'in_reply_to_user_id': '1562960843276357633',
#    'author_id': '733753601265434624',
#    'reply_settings': 'everyone',
#    'conversation_id': '1589088654039093250',
#    'id': '1589405794310983680',
#    'created_at': '2022-11-06T23:54:05.000Z',
#    'lang': 'en',
#    'source': 'Twitter Web App',
#    'text': '@lapis_lazuli11 Also, "bruh" made me lol. You still have you. And your talents &amp; sharp mind &amp; hope for medical improvements to come.\nTell your dad you have mild Ebola. He probably didn\'t know what that was, either, but found out, right? Here\'s a monkey refusing to listen to cheer you up. 🙉',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 1,
#     'quote_count': 0},
#    'edit_history_tweet_ids': ['1589405794310983680']},
#   {'referenced_tweets': [{'type': 'retweeted', 'id': '1588961620440813568'}],
#    'author_id': '316467175',
#    'reply_settings': 'everyone',
#    'conversation_id': '1589405787688173568',
#    'id': '1589405787688173568',
#    'created_at': '2022-11-06T23:54:04.000Z',
#    'lang': 'es',
#    'source': 'Twitter for Android',
#    'text': 'RT @richyuno64: El PP culpó del Jak42 a la cúpula militar\ndel 11M a ETA \nd la crisis del Ébola, a la enfermera\ndel accidente del Alvia, al…',
#    'public_metrics': {'retweet_count': 972,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'edit_history_tweet_ids': ['1589405787688173568']},
#   {'referenced_tweets': [{'type': 'retweeted', 'id': '1589391109868093441'}],
#    'author_id': '1222739029025873920',
#    'reply_settings': 'everyone',
#    'conversation_id': '1589405487325675520',
#    'id': '1589405487325675520',
#    'created_at': '2022-11-06T23:52:52.000Z',
#    'lang': 'en',
#    'source': 'Twitter Web App',
#    'text': 'RT @DelthiaRicks: Uganda extends lockdowns as #Ebola spreads. A 3-wk lockdown has been ordered in 2 districts at the center of the outbreak…',
#    'public_metrics': {'retweet_count': 17,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'edit_history_tweet_ids': ['1589405487325675520']},
#   {'referenced_tweets': [{'type': 'retweeted', 'id': '1589369212413566976'}],
#    'author_id': '743069606106009600',
#    'reply_settings': 'everyone',
#    'conversation_id': '1589405435572137985',
#    'id': '1589405435572137985',
#    'created_at': '2022-11-06T23:52:40.000Z',
#    'lang': 'es',
#    'source': 'Twitter for Android',
#    'text': 'RT @Ivanjode: El PP, partido condenado y más corrupto de Europa fue el gestor del Prestige, el Yak-42, el Ébola o el 11-M. Después de todo…',
#    'public_metrics': {'retweet_count': 726,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'edit_history_tweet_ids': ['1589405435572137985']},
#   {'referenced_tweets': [{'type': 'retweeted', 'id': '1589369212413566976'}],
#    'author_id': '408551247',
#    'reply_settings': 'everyone',
#    'conversation_id': '1589405260535463937',
#    'id': '1589405260535463937',
#    'created_at': '2022-11-06T23:51:58.000Z',
#    'lang': 'es',
#    'source': 'Twitter for Android',
#    'text': 'RT @Ivanjode: El PP, partido condenado y más corrupto de Europa fue el gestor del Prestige, el Yak-42, el Ébola o el 11-M. Después de todo…',
#    'public_metrics': {'retweet_count': 726,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'edit_history_tweet_ids': ['1589405260535463937']},
#   {'referenced_tweets': [{'type': 'replied_to', 'id': '1589360329061867520'}],
#    'in_reply_to_user_id': '1242872429183107077',
#    'author_id': '2517410777',
#    'reply_settings': 'everyone',
#    'conversation_id': '1589357939634376704',
#    'id': '1589405038350569472',
#    'created_at': '2022-11-06T23:51:05.000Z',
#    'lang': 'en',
#    'source': 'Twitter Web App',
#    'text': '@SavMondo @CallumWilson @NUFCgallowgate @NUFC As a younger man, I took speed and lots of it. Never even had the fuckin sniffles. Now I’m on cod liver oil capsules, aspirin, vitamin D, vitamin C but I’ve got piles the size of goosegogs and the symptoms of fuckin ebola every week. 🤣🤣🤣',
#    'public_metrics': {'retweet_count': 1,
#     'reply_count': 1,
#     'like_count': 5,
#     'quote_count': 0},
#    'edit_history_tweet_ids': ['1589405038350569472']},
#   {'referenced_tweets': [{'type': 'replied_to', 'id': '1589369212413566976'}],
#    'in_reply_to_user_id': '786833353957867522',
#    'author_id': '1475987889230131205',
#    'reply_settings': 'everyone',
#    'conversation_id': '1589369212413566976',
#    'id': '1589404921648263170',
#    'created_at': '2022-11-06T23:50:37.000Z',
#    'lang': 'es',
#    'source': 'Twitter for Android',
#    'text': '@Ivanjode El ébola se gestionó mal? Solo murió un perro, con Sanchinflas &amp; Chepas y el covid han muerto decenas de miles de personas!!',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 2,
#     'quote_count': 0},
#    'edit_history_tweet_ids': ['1589404921648263170']},
#   {'author_id': '2864407958',
#    'reply_settings': 'everyone',
#    'conversation_id': '1589404556081127424',
#    'id': '1589404556081127424',
#    'created_at': '2022-11-06T23:49:10.000Z',
#    'lang': 'en',
#    'source': 'twittbot.net',
#    'text': 'tbh ebola is probably just another mononoke',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'edit_history_tweet_ids': ['1589404556081127424']},
#   {'referenced_tweets': [{'type': 'replied_to', 'id': '1589400598012911619'}],
#    'in_reply_to_user_id': '936387097564508162',
#    'author_id': '1220026634209808384',
#    'reply_settings': 'everyone',
#    'conversation_id': '1589400598012911619',
#    'id': '1589404548258750464',
#    'created_at': '2022-11-06T23:49:08.000Z',
#    'lang': 'pt',
#    'source': 'Twitter for iPhone',
#    'text': '@MatheusMafra08 ebola? 😳',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 1,
#     'like_count': 1,
#     'quote_count': 0},
#    'edit_history_tweet_ids': ['1589404548258750464']},
#   {'referenced_tweets': [{'type': 'retweeted', 'id': '1588961620440813568'}],
#    'author_id': '865506068',
#    'reply_settings': 'everyone',
#    'conversation_id': '1589404128450527232',
#    'id': '1589404128450527232',
#    'created_at': '2022-11-06T23:47:28.000Z',
#    'lang': 'es',
#    'source': 'Twitter for Android',
#    'text': 'RT @richyuno64: El PP culpó del Jak42 a la cúpula militar\ndel 11M a ETA \nd la crisis del Ébola, a la enfermera\ndel accidente del Alvia, al…',
#    'public_metrics': {'retweet_count': 972,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'edit_history_tweet_ids': ['1589404128450527232']}],
#  'includes': {'users': [{'verified': False,
#     'id': '2751880866',
#     'public_metrics': {'followers_count': 138,
#      'following_count': 415,
#      'tweet_count': 3180,
#      'listed_count': 0},
#     'username': 'grandmasterorge',
#     'name': 'George May',
#     'created_at': '2014-08-21T11:16:46.000Z',
#     'description': 'Mountain bikes, surfing, skiing, chemistry.'},
#    {'verified': False,
#     'id': '518957800',
#     'public_metrics': {'followers_count': 230,
#      'following_count': 106,
#      'tweet_count': 4172,
#      'listed_count': 1},
#     'username': 'KeepitdarkIan',
#     'name': 'Captain Pugwash',
#     'created_at': '2012-03-08T22:46:55.000Z',
#     'description': 'Lock down sceptic\nGenesis fan (the band not the Bible book!)\n"No" to any mandatory vaccine'},
#    {'verified': False,
#     'id': '1213257465447403520',
#     'public_metrics': {'followers_count': 1005,
#      'following_count': 858,
#      'tweet_count': 198849,
#      'listed_count': 5},
#     'username': 'Ficcion9',
#     'name': 'Ficcion',
#     'created_at': '2020-01-04T00:35:09.000Z',
#     'description': 'Cuenta de respaldo @Ficcion2_0'},
#    {'verified': False,
#     'id': '1520550645794758656',
#     'public_metrics': {'followers_count': 21,
#      'following_count': 342,
#      'tweet_count': 1708,
#      'listed_count': 0},
#     'username': 'JavierG12685349',
#     'name': 'JG',
#     'created_at': '2022-04-30T23:49:43.000Z',
#     'description': 'La segunda a la izquierda'},
#    {'verified': False,
#     'id': '355299869',
#     'public_metrics': {'followers_count': 1168,
#      'following_count': 1829,
#      'tweet_count': 23115,
#      'listed_count': 0},
#     'username': 'Juandonosti2012',
#     'name': 'Juan Donosti',
#     'created_at': '2011-08-15T04:11:08.000Z',
#     'description': 'Tlamatini (pensador  Nuestroamericano)'},
#    {'verified': False,
#     'id': '733753601265434624',
#     'public_metrics': {'followers_count': 627,
#      'following_count': 4975,
#      'tweet_count': 8747,
#      'listed_count': 13},
#     'username': 'CLT_truth',
#     'name': 'charlotte',
#     'created_at': '2016-05-20T20:17:45.000Z',
#     'description': 'CharlotteCitizen99@gmail.com see https://t.co/tx0mfeDtur (warn:lang) see #CLT leadership resp. to police misconduct  MORE TO COME until crime stops &reform'},
#    {'verified': False,
#     'id': '1562960843276357633',
#     'public_metrics': {'followers_count': 421,
#      'following_count': 192,
#      'tweet_count': 155,
#      'listed_count': 2},
#     'username': 'lapis_lazuli11',
#     'name': 'Amy',
#     'created_at': '2022-08-26T00:31:26.000Z',
#     'description': 'Severe ME/CFS since 2021. 26 y.o.'},
#    {'verified': False,
#     'id': '316467175',
#     'public_metrics': {'followers_count': 1037,
#      'following_count': 1681,
#      'tweet_count': 36661,
#      'listed_count': 1},
#     'username': 'Tuhoajatar',
#     'name': 'Tuhoajatar',
#     'created_at': '2011-06-13T14:02:48.000Z',
#     'description': 'Profundamente identificado con el 15M, que siga la revolución en busca de justicia'},
#    {'verified': False,
#     'id': '1222739029025873920',
#     'public_metrics': {'followers_count': 626,
#      'following_count': 1107,
#      'tweet_count': 18928,
#      'listed_count': 5},
#     'username': 'Angela_Biochem',
#     'name': 'Angela Barnett',
#     'created_at': '2020-01-30T04:32:42.000Z',
#     'description': 'Biochem Phd/birdwatcher/coffee aficionado'},
#    {'verified': False,
#     'id': '743069606106009600',
#     'public_metrics': {'followers_count': 389,
#      'following_count': 930,
#      'tweet_count': 36160,
#      'listed_count': 2},
#     'username': 'colibri_maine11',
#     'name': 'Colibri_maine',
#     'created_at': '2016-06-15T13:16:14.000Z',
#     'description': 'veo,pienso y opino'},
#    {'verified': False,
#     'id': '408551247',
#     'public_metrics': {'followers_count': 422,
#      'following_count': 761,
#      'tweet_count': 244821,
#      'listed_count': 25},
#     'username': 'Maria_HJ97',
#     'name': 'Mary HJ',
#     'created_at': '2011-11-09T15:35:23.000Z',
#     'description': '"la alegría era un arma superior al odio, las sonrisas más útiles, más feroces que los gestos de rabia y desaliento"\nGraduada en Economía'},
#    {'verified': False,
#     'id': '2517410777',
#     'public_metrics': {'followers_count': 693,
#      'following_count': 108,
#      'tweet_count': 9770,
#      'listed_count': 0},
#     'username': 'FilthyJeesus',
#     'name': 'Filthy Jesus',
#     'created_at': '2014-04-29T19:11:21.000Z',
#     'description': 'I’m a Socialist, Newcastle United fan who likes John Lennon, Lana Del Rey, T Rex, Amy Winehouse, Janis Joplin and alcohol.'},
#    {'verified': False,
#     'id': '1242872429183107077',
#     'public_metrics': {'followers_count': 32482,
#      'following_count': 5509,
#      'tweet_count': 41392,
#      'listed_count': 38},
#     'username': 'SavMondo',
#     'name': 'Sav Mondo',
#     'created_at': '2020-03-25T17:54:34.000Z',
#     'description': 'Onlyfans of NUFC Twitter and wearer of mystery knickers. Lover of attention. NUFC, AFC, NCFC & F1.'},
#    {'verified': False,
#     'id': '1475987889230131205',
#     'public_metrics': {'followers_count': 424,
#      'following_count': 937,
#      'tweet_count': 10631,
#      'listed_count': 2},
#     'username': 'LeonSKe72492768',
#     'name': 'Leon S. Kennedy 🔺️🌈🇪🇦',
#     'created_at': '2021-12-29T00:32:10.000Z',
#     'description': 'Economista mar%cón y facha'},
#    {'verified': False,
#     'id': '786833353957867522',
#     'public_metrics': {'followers_count': 21695,
#      'following_count': 1067,
#      'tweet_count': 19617,
#      'listed_count': 0},
#     'username': 'Ivanjode',
#     'name': 'Ivanjode',
#     'created_at': '2016-10-14T07:37:45.000Z',
#     'description': 'Para tweet fijado el que tengo aquí colgado.'},
#    {'verified': False,
#     'id': '2864407958',
#     'public_metrics': {'followers_count': 34,
#      'following_count': 213,
#      'tweet_count': 84500,
#      'listed_count': 1},
#     'username': 'Kusuri_Bot_',
#     'name': 'クスリウリ',
#     'created_at': '2014-10-19T08:18:45.000Z',
#     'description': ''},
#    {'verified': False,
#     'id': '1220026634209808384',
#     'public_metrics': {'followers_count': 124,
#      'following_count': 92,
#      'tweet_count': 1049,
#      'listed_count': 0},
#     'username': 'alisonkienenn',
#     'name': 'kienen',
#     'created_at': '2020-01-22T16:53:27.000Z',
#     'description': 'nothing like one day after the other day'},
#    {'verified': False,
#     'id': '936387097564508162',
#     'public_metrics': {'followers_count': 461,
#      'following_count': 247,
#      'tweet_count': 9554,
#      'listed_count': 0},
#     'username': 'MatheusMafra08',
#     'name': 'Mafra🌗',
#     'created_at': '2017-12-01T00:10:56.000Z',
#     'description': ''},
#    {'verified': False,
#     'id': '865506068',
#     'public_metrics': {'followers_count': 960,
#      'following_count': 2038,
#      'tweet_count': 21022,
#      'listed_count': 7},
#     'username': 'roc_leevancleef',
#     'name': 'Rocío StopTTIP',
#     'created_at': '2012-10-07T00:14:44.000Z',
#     'description': ''}]},
#  'meta': {'newest_id': '1589407031303491584',
#   'oldest_id': '1589404128450527232',
#   'result_count': 14,
#   'next_token': 'b26v89c19zqg8o3fpzen8dijljfxg1wrlk8oujymfgkfx'}}

# %%
import sys
sys.path.append("C:/Users/szkum/NetSI/Euphoria-Networks/src")

from data.TweetCollector import TweetCollector

# %%
tst_1 = TweetCollector("ebola", "2022-11-02", "2022-11-07", 10)

# %%
tst_1()
# Out:
# Endpoint Response Code: 200
# {'data': [{'lang': 'en',
#    'edit_history_tweet_ids': ['1589407031303491584'],
#    'conversation_id': '1589063446649507840',
#    'referenced_tweets': [{'type': 'replied_to', 'id': '1589106068247875585'}],
#    'author_id': '2751880866',
#    'source': 'Twitter for Android',
#    'id': '1589407031303491584',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': '@KeepitdarkIan @BarryHunt008 Worked for smallpox, ebola, rabies and polio, right?',
#    'in_reply_to_user_id': '518957800',
#    'reply_settings': 'everyone',
#    'created_at': '2022-11-06T23:59:00.000Z'},
#   {'lang': 'es',
#    'edit_history_tweet_ids': ['1589406475306270720'],
#    'conversation_id': '1589406475306270720',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1589369212413566976'}],
#    'author_id': '1213257465447403520',
#    'source': 'Twitter for Android',
#    'id': '1589406475306270720',
#    'public_metrics': {'retweet_count': 726,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @Ivanjode: El PP, partido condenado y más corrupto de Europa fue el gestor del Prestige, el Yak-42, el Ébola o el 11-M. Después de todo…',
#    'reply_settings': 'everyone',
#    'created_at': '2022-11-06T23:56:48.000Z'},
#   {'lang': 'es',
#    'edit_history_tweet_ids': ['1589406370914533376'],
#    'conversation_id': '1589406370914533376',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1588961620440813568'}],
#    'author_id': '1520550645794758656',
#    'source': 'Twitter Web App',
#    'id': '1589406370914533376',
#    'public_metrics': {'retweet_count': 972,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @richyuno64: El PP culpó del Jak42 a la cúpula militar\ndel 11M a ETA \nd la crisis del Ébola, a la enfermera\ndel accidente del Alvia, al…',
#    'reply_settings': 'everyone',
#    'created_at': '2022-11-06T23:56:23.000Z'},
#   {'lang': 'it',
#    'edit_history_tweet_ids': ['1589406126436937728'],
#    'conversation_id': '1589406126436937728',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1588813959704236033'}],
#    'author_id': '355299869',
#    'source': 'Twitter Web App',
#    'id': '1589406126436937728',
#    'public_metrics': {'retweet_count': 171,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "RT @ElGusty201: Bombe atomiche?\n\nNo! Pandemie.\n\nPutin ha invaso Ucraina perché il NWO, stava preparando per quest' autunno una febbre viral…",
#    'reply_settings': 'everyone',
#    'created_at': '2022-11-06T23:55:24.000Z'},
#   {'lang': 'en',
#    'edit_history_tweet_ids': ['1589405794310983680'],
#    'conversation_id': '1589088654039093250',
#    'referenced_tweets': [{'type': 'replied_to', 'id': '1589088654039093250'}],
#    'author_id': '733753601265434624',
#    'source': 'Twitter Web App',
#    'id': '1589405794310983680',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 1,
#     'quote_count': 0},
#    'text': '@lapis_lazuli11 Also, "bruh" made me lol. You still have you. And your talents &amp; sharp mind &amp; hope for medical improvements to come.\nTell your dad you have mild Ebola. He probably didn\'t know what that was, either, but found out, right? Here\'s a monkey refusing to listen to cheer you up. 🙉',
#    'in_reply_to_user_id': '1562960843276357633',
#    'reply_settings': 'everyone',
#    'created_at': '2022-11-06T23:54:05.000Z'},
#   {'lang': 'es',
#    'edit_history_tweet_ids': ['1589405787688173568'],
#    'conversation_id': '1589405787688173568',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1588961620440813568'}],
#    'author_id': '316467175',
#    'source': 'Twitter for Android',
#    'id': '1589405787688173568',
#    'public_metrics': {'retweet_count': 972,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @richyuno64: El PP culpó del Jak42 a la cúpula militar\ndel 11M a ETA \nd la crisis del Ébola, a la enfermera\ndel accidente del Alvia, al…',
#    'reply_settings': 'everyone',
#    'created_at': '2022-11-06T23:54:04.000Z'},
#   {'lang': 'en',
#    'edit_history_tweet_ids': ['1589405487325675520'],
#    'conversation_id': '1589405487325675520',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1589391109868093441'}],
#    'author_id': '1222739029025873920',
#    'source': 'Twitter Web App',
#    'id': '1589405487325675520',
#    'public_metrics': {'retweet_count': 17,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @DelthiaRicks: Uganda extends lockdowns as #Ebola spreads. A 3-wk lockdown has been ordered in 2 districts at the center of the outbreak…',
#    'reply_settings': 'everyone',
#    'created_at': '2022-11-06T23:52:52.000Z'},
#   {'lang': 'es',
#    'edit_history_tweet_ids': ['1589405435572137985'],
#    'conversation_id': '1589405435572137985',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1589369212413566976'}],
#    'author_id': '743069606106009600',
#    'source': 'Twitter for Android',
#    'id': '1589405435572137985',
#    'public_metrics': {'retweet_count': 726,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @Ivanjode: El PP, partido condenado y más corrupto de Europa fue el gestor del Prestige, el Yak-42, el Ébola o el 11-M. Después de todo…',
#    'reply_settings': 'everyone',
#    'created_at': '2022-11-06T23:52:40.000Z'},
#   {'lang': 'es',
#    'edit_history_tweet_ids': ['1589405260535463937'],
#    'conversation_id': '1589405260535463937',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1589369212413566976'}],
#    'author_id': '408551247',
#    'source': 'Twitter for Android',
#    'id': '1589405260535463937',
#    'public_metrics': {'retweet_count': 726,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @Ivanjode: El PP, partido condenado y más corrupto de Europa fue el gestor del Prestige, el Yak-42, el Ébola o el 11-M. Después de todo…',
#    'reply_settings': 'everyone',
#    'created_at': '2022-11-06T23:51:58.000Z'}],
#  'includes': {'users': [{'verified': False,
#     'username': 'grandmasterorge',
#     'public_metrics': {'followers_count': 138,
#      'following_count': 415,
#      'tweet_count': 3180,
#      'listed_count': 0},
#     'name': 'George May',
#     'description': 'Mountain bikes, surfing, skiing, chemistry.',
#     'id': '2751880866',
#     'created_at': '2014-08-21T11:16:46.000Z'},
#    {'verified': False,
#     'username': 'KeepitdarkIan',
#     'public_metrics': {'followers_count': 230,
#      'following_count': 106,
#      'tweet_count': 4172,
#      'listed_count': 1},
#     'name': 'Captain Pugwash',
#     'description': 'Lock down sceptic\nGenesis fan (the band not the Bible book!)\n"No" to any mandatory vaccine',
#     'id': '518957800',
#     'created_at': '2012-03-08T22:46:55.000Z'},
#    {'verified': False,
#     'username': 'Ficcion9',
#     'public_metrics': {'followers_count': 1005,
#      'following_count': 858,
#      'tweet_count': 198849,
#      'listed_count': 5},
#     'name': 'Ficcion',
#     'description': 'Cuenta de respaldo @Ficcion2_0',
#     'id': '1213257465447403520',
#     'created_at': '2020-01-04T00:35:09.000Z'},
#    {'verified': False,
#     'username': 'JavierG12685349',
#     'public_metrics': {'followers_count': 21,
#      'following_count': 342,
#      'tweet_count': 1708,
#      'listed_count': 0},
#     'name': 'JG',
#     'description': 'La segunda a la izquierda',
#     'id': '1520550645794758656',
#     'created_at': '2022-04-30T23:49:43.000Z'},
#    {'verified': False,
#     'username': 'Juandonosti2012',
#     'public_metrics': {'followers_count': 1168,
#      'following_count': 1829,
#      'tweet_count': 23115,
#      'listed_count': 0},
#     'name': 'Juan Donosti',
#     'description': 'Tlamatini (pensador  Nuestroamericano)',
#     'id': '355299869',
#     'created_at': '2011-08-15T04:11:08.000Z'},
#    {'verified': False,
#     'username': 'CLT_truth',
#     'public_metrics': {'followers_count': 627,
#      'following_count': 4975,
#      'tweet_count': 8747,
#      'listed_count': 13},
#     'name': 'charlotte',
#     'description': 'CharlotteCitizen99@gmail.com see https://t.co/tx0mfeDtur (warn:lang) see #CLT leadership resp. to police misconduct  MORE TO COME until crime stops &reform',
#     'id': '733753601265434624',
#     'created_at': '2016-05-20T20:17:45.000Z'},
#    {'verified': False,
#     'username': 'lapis_lazuli11',
#     'public_metrics': {'followers_count': 421,
#      'following_count': 192,
#      'tweet_count': 155,
#      'listed_count': 2},
#     'name': 'Amy',
#     'description': 'Severe ME/CFS since 2021. 26 y.o.',
#     'id': '1562960843276357633',
#     'created_at': '2022-08-26T00:31:26.000Z'},
#    {'verified': False,
#     'username': 'Tuhoajatar',
#     'public_metrics': {'followers_count': 1037,
#      'following_count': 1681,
#      'tweet_count': 36661,
#      'listed_count': 1},
#     'name': 'Tuhoajatar',
#     'description': 'Profundamente identificado con el 15M, que siga la revolución en busca de justicia',
#     'id': '316467175',
#     'created_at': '2011-06-13T14:02:48.000Z'},
#    {'verified': False,
#     'username': 'Angela_Biochem',
#     'public_metrics': {'followers_count': 626,
#      'following_count': 1107,
#      'tweet_count': 18928,
#      'listed_count': 5},
#     'name': 'Angela Barnett',
#     'description': 'Biochem Phd/birdwatcher/coffee aficionado',
#     'id': '1222739029025873920',
#     'created_at': '2020-01-30T04:32:42.000Z'},
#    {'verified': False,
#     'username': 'colibri_maine11',
#     'public_metrics': {'followers_count': 389,
#      'following_count': 930,
#      'tweet_count': 36160,
#      'listed_count': 2},
#     'name': 'Colibri_maine',
#     'description': 'veo,pienso y opino',
#     'id': '743069606106009600',
#     'created_at': '2016-06-15T13:16:14.000Z'},
#    {'verified': False,
#     'username': 'Maria_HJ97',
#     'public_metrics': {'followers_count': 422,
#      'following_count': 761,
#      'tweet_count': 244821,
#      'listed_count': 25},
#     'name': 'Mary HJ',
#     'description': '"la alegría era un arma superior al odio, las sonrisas más útiles, más feroces que los gestos de rabia y desaliento"\nGraduada en Economía',
#     'id': '408551247',
#     'created_at': '2011-11-09T15:35:23.000Z'}]},
#  'meta': {'newest_id': '1589407031303491584',
#   'oldest_id': '1589405260535463937',
#   'result_count': 9,
#   'next_token': 'b26v89c19zqg8o3fpzen8dijn2a53etr4umgj5fns6kxp'}}
